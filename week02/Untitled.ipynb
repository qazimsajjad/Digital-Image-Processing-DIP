# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./flower.tif')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(img.shape)
plt.imshow(img)
# Out:
# (513, 513, 3)

# %%
blue_img = img.copy()
blue_img[:,:,0] = 0
blue_img[:,:,1] = 0
plt.imshow(blue_img)

# %%
img = cv2.imread('./Fig0219(rose1024).tif',0)
plt.imshow(img, cmap='gray');plt.title('orignal')
plt.show()
averg = (img+img+img)/3
plt.imshow(averg, 'gray'); plt.title("averaged")
plt.show()

# %%
img =cv2.imread('./flower.tif')
img =cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img, 'gray')
img[0]
# Out:
# array([[127, 113, 197],
#        [131, 117, 203],
#        [136, 121, 207],
#        ...,
#        [120,  89, 170],
#        [126,  96, 178],
#        [122,  91, 175]], dtype=uint8)

# %%
img2 = img.copy()
img2[:,:,1] = img2[:,:,1]-100
plt.imshow(img2)

# %%
img = np.zeros((200,200), dtype=np.int32)
frame1 = img.copy()
frame2 = img.copy()
frame1[100:150,50:180] = 255
frame2[100:180,60:100] = 255
plt.imshow(frame1, 'gray'); plt.title('frame1'); plt.axis('off')
plt.show()
plt.imshow(frame2, 'gray'); plt.title('frame1'); plt.axis('off')
plt.show()
result = frame1-frame2
plt.imshow(result, 'gray'); plt.title('frame1'); plt.axis('off'); plt.show()
